# %%
def fill_gun_stolen(row):
    if row['gun_stolen'] == 'unkown':
        return row['gun_stolen']
    else:
        return "stolen"

# axis = 1 means do it to the columns (0 is the rows)
upd_gun_stolen['gun_stolen'] = upd_gun_stolen.apply(fill_gun_stolen, axis=1)

# %%
import pandas as pd
import plotly.express as px
import numpy as np
import seaborn as sns

# %%
gun_violence = pd.read_csv("gun-violence-data_01-2013_03-2018 2.csv")

# %%
gun_violence.head()
# Out:
#    incident_id        date           state city_or_county  \
# 0       461105  2013-01-01    Pennsylvania     Mckeesport
# 1       460726  2013-01-01      California      Hawthorne
# 2       478855  2013-01-01            Ohio         Lorain
# 3       478925  2013-01-05        Colorado         Aurora
# 4       478959  2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# ...

# %%
gun_violence.tail(5)
# Out:
#         incident_id        date      state city_or_county  \
# 239672      1083142  2018-03-31  Louisiana          Rayne
# 239673      1083139  2018-03-31  Louisiana   Natchitoches
# 239674      1083151  2018-03-31  Louisiana         Gretna
# 239675      1082514  2018-03-31      Texas        Houston
# 239676      1081940  2018-03-31      Maine   Norridgewock
#
#                                    address  n_killed  n_injured  \
# 239672  North Riceland Road and Highway 90         0          0
# 239673                      247 Keyser Ave         1          0
# 239674           1300 block of Cook Street         0          1
# 239675              12630 Ashford Point Dr         1          0
# 239676                    434 Skowhegan Rd         2          0
#
#                                              incident_url  \
# 239672  http://www.gunviolencearchive.org/incident/108...
# 239673  http://www.gunviolencearchive.org/incident/108...
# ...

# %%
gun_violence.columns
# Out:
# Index(['incident_id', 'date', 'state', 'city_or_county', 'address', 'n_killed',
#        'n_injured', 'incident_url', 'source_url',
#        'incident_url_fields_missing', 'congressional_district', 'gun_stolen',
#        'gun_type', 'incident_characteristics', 'latitude',
#        'location_description', 'longitude', 'n_guns_involved', 'notes',
#        'participant_age', 'participant_age_group', 'participant_gender',
#        'participant_name', 'participant_relationship', 'participant_status',
#        'participant_type', 'sources', 'state_house_district',
#        'state_senate_district'],
#       dtype='object')

# %%
gun_violence.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239677 entries, 0 to 239676
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   incident_id                  239677 non-null  int64
#  1   date                         239677 non-null  object
#  2   state                        239677 non-null  object
#  3   city_or_county               239677 non-null  object
#  4   address                      223180 non-null  object
#  5   n_killed                     239677 non-null  int64
#  6   n_injured                    239677 non-null  int64
#  7   incident_url                 239677 non-null  object
#  8   source_url                   239209 non-null  object
#  9   incident_url_fields_missing  239677 non-null  bool
#  10  congressional_district       227733 non-null  float64
#  11  gun_stolen                   140179 non-null  object
# ...

# %%
drop_list = ["incident_url", "source_url", "location_description", "notes", "sources", "incident_url_fields_missing", "participant_relationship", "congressional_district", "state_house_district", "state_senate_district", "latitude", "longitude", "address"]

# %%
upd_gun_violence = gun_violence.drop( drop_list, axis = 1)

# %%
upd_gun_violence.shape
# Out:
# (239677, 16)

# %%
upd_gun_violence.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239677 entries, 0 to 239676
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   incident_id               239677 non-null  int64
#  1   date                      239677 non-null  object
#  2   state                     239677 non-null  object
#  3   city_or_county            239677 non-null  object
#  4   n_killed                  239677 non-null  int64
#  5   n_injured                 239677 non-null  int64
#  6   gun_stolen                140179 non-null  object
#  7   gun_type                  140226 non-null  object
#  8   incident_characteristics  239351 non-null  object
#  9   n_guns_involved           140226 non-null  float64
#  10  participant_age           147379 non-null  object
#  11  participant_age_group     197558 non-null  object
#  12  participant_gender        203315 non-null  object
# ...

# %%
upd_gun_violence.columns
# Out:
# Index(['incident_id', 'date', 'state', 'city_or_county', 'n_killed',
#        'n_injured', 'gun_stolen', 'gun_type', 'incident_characteristics',
#        'n_guns_involved', 'participant_age', 'participant_age_group',
#        'participant_gender', 'participant_name', 'participant_status',
#        'participant_type'],
#       dtype='object')

# %%
upd_gun_violence.head(15)
# Out:
#     incident_id        date                 state city_or_county  n_killed  \
# 0        461105  2013-01-01          Pennsylvania     Mckeesport         0
# 1        460726  2013-01-01            California      Hawthorne         1
# 2        478855  2013-01-01                  Ohio         Lorain         1
# 3        478925  2013-01-05              Colorado         Aurora         4
# 4        478959  2013-01-07        North Carolina     Greensboro         2
# 5        478948  2013-01-07              Oklahoma          Tulsa         4
# 6        479363  2013-01-19            New Mexico    Albuquerque         5
# 7        479374  2013-01-21             Louisiana    New Orleans         0
# 8        479389  2013-01-21            California      Brentwood         0
# 9        492151  2013-01-23              Maryland      Baltimore         1
# 10       491674  2013-01-23             Tennessee    Chattanooga         1
# ...

# %%
# huishu_gun_violence['gun_stolen'] = huishu_gun_violence['gun_stolen'].replace('None','unknown')
# huishu_gun_violence.head(5)
upd_gun_stolen = gun_violence.drop( drop_list, axis = 1)
upd_gun_stolen['gun_stolen'] = upd_gun_stolen['gun_stolen'].fillna("not_known")

# %%
upd_gun_stolen.head(5)
# Out:
#    incident_id        date           state city_or_county  n_killed  \
# 0       461105  2013-01-01    Pennsylvania     Mckeesport         0
# 1       460726  2013-01-01      California      Hawthorne         1
# 2       478855  2013-01-01            Ohio         Lorain         1
# 3       478925  2013-01-05        Colorado         Aurora         4
# 4       478959  2013-01-07  North Carolina     Greensboro         2
#
#    n_injured              gun_stolen                gun_type  \
# 0          4               not_known                     NaN
# 1          3               not_known                     NaN
# 2          3  0::Unknown||1::Unknown  0::Unknown||1::Unknown
# 3          0               not_known                     NaN
# 4          2  0::Unknown||1::Unknown  0::Handgun||1::Handgun
#
#                             incident_characteristics  n_guns_involved  \
# 0  Shot - Wounded/Injured||Mass Shooting (4+ vict...              NaN
# ...

# %%
def fill_gun_stolen(row):
    if row['ç'] == "N/A":
        row['gun_stolen'] = "unknown"
    else:
        row['gun_stolen'] = "stolen"

# axis = 1 means do it to the columns (0 is the rows)
upd_gun_violence['gun_stolen'] = upd_gun_violence.apply(lambda row : fill_gun_stolen(upd_gun_violence['stolen'][i]), axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/ds_env/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/miniconda3/envs/ds_env/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniconda3/envs/ds_env/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'stolen'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
upd_gun_violence['gun_stolen']
# Out:
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#           ...
# 239672    None
# 239673    None
# 239674    None
# 239675    None
# 239676    None
# Name: gun_stolen, Length: 239677, dtype: object

# %%
upd_gun_violence[upd_gun_violence["gun_stolen"].isnull()].gun_stolen.unique()
# Out:
# array([nan], dtype=object)

# %%
import plotly.graph_objects as go

import pandas as pd
daf = pd.read_csv("gun-violence-data_01-2013_03-2018 2.csv")

for col in daf.columns:
    daf[col] = daf[col].astype(rr)
#This is the hover values
daf['text'] = daf['state'] + '<br>' + \
    'Deaths ' + daf['n_killed'] + ' Injured ' + daf['n_injured']

figure = go.Figure(data=go.Choropleth(
    locations=daf['state'],
    z=daf['n_killed'].astype(int),
    locationmode='USA-states',
    colorscale='Reds',
    autocolorscale=False,
    text=daf['text'], # hover text
    marker_line_color='white', # line markers between states
    colorbar_title="Number of People Killed"))

figure.update_layout(
    title_text='People Killed By Gun Violence By State in the USA<br>(Hover for breakdown)',
    geo = dict(
        scope="usa",
        projection=go.layout.geo.Projection(type = 'albers usa'),
        showlakes=True, # lakes
        lakecolor='rgb(255, 255, 255)')
)



figure.show()
#This graph is complete.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [104], in <cell line: 6>()
#       4 daf = pd.read_csv("gun-violence-data_01-2013_03-2018 2.csv")
#       6 for col in daf.columns:
# ----> 7     daf[col] = daf[col].astype(rr)
#       8 #This is the hover values
#       9 daf['text'] = daf['state'] + '<br>' + \
#      10     'Deaths ' + daf['n_killed'] + ' Injured ' + daf['n_injured']
#
# NameError: name 'rr' is not defined

# %%
import plotly.express as px
gun_violence_sc = px.read.csv("gun-violence-data_01-2013_03-2018 2.csv")
#df = px.data.iris()

scatter.fig = px.scatter(gun_violence_sc, x='state', y='n_killed', color='n_injured', size='')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [91], in <cell line: 2>()
#       1 import plotly.express as px
# ----> 2 gun_violence_sc = px.read.csv("gun-violence-data_01-2013_03-2018 2.csv")
#       3 #df = px.data.iris()
#       5 scatter.fig = px.scatter(gun_violence_sc, x='state', y='n_killed', color='n_injured', size='')
#
# AttributeError: module 'plotly.express' has no attribute 'read'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [101], in <cell line: 1>()
# ----> 1 print(df.columns)
#
# NameError: name 'df' is not defined

# %%
import plotly.express as px
dof = pd.read.csv("gun-violence-data_01-2013_03-2018 2.csv")


dof = dof[['state', 'city_or_county','n_killed']]

fig = px.choropleth(dof,
                    locations='state', 
                    locationmode="USA-states", 
                    scope="usa",
                    colorscale = 'blues',
                    color_continuous_scale=("thermal_r"),
                    )
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [90], in <cell line: 2>()
#       1 import plotly.express as px
# ----> 2 dof = pd.read.csv("gun-violence-data_01-2013_03-2018 2.csv")
#       5 dof = dof[['state', 'city_or_county','n_killed']]
#       7 fig = px.choropleth(dof,
#       8                     locations='state',
#       9                     locationmode="USA-states",
#    (...)
#      12                     color_continuous_scale=("thermal_r"),
#      13                     )
#
# File ~/miniconda3/envs/ds_env/lib/python3.8/site-packages/pandas/__init__.py:261, in __getattr__(name)
#     257     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     259     return _SparseArray
# --> 261 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'read'
